# %% [markdown]
# # Load data and process for analysis

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # If you have done cycling for this cell Only process once!!!!!!!!!!!!!!!!!!!!!

# %% [markdown]
# ## for cell 1

# %%
################# This is first time testing data
cell_id = '20240830001'

filename =cell_id+ '.xlsx'
cycle = pd.read_excel(filename,sheet_name='cycle')
step = pd.read_excel(filename,sheet_name='step')
details = pd.read_excel(filename,sheet_name='record')

cycle.to_csv(cell_id+'_cycle.csv')
step.to_csv(cell_id+'_step.csv')
details.to_csv(cell_id+'_details.csv')
# Out:
# C:\miniconda\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %% [markdown]
# ## for cell 2

# %%
# ################# This is second time testing data
# cell_id = '20240305001'

# filename ='./Cell_raw_data/'+cell_id+ '.xlsx'
# cycle = pd.read_excel(filename,sheet_name='cycle')
# step = pd.read_excel(filename,sheet_name='step')
# details = pd.read_excel(filename,sheet_name='record')

# cycle.to_csv(cell_id+'_cycle.csv')
# step.to_csv(cell_id+'_step.csv')
# details.to_csv(cell_id+'_details.csv')

# %% [markdown]
# ## for cell 3

# %%
################ This is second time testing data
# cell_id = '20240306001'

# filename ='./Cell_raw_data/'+cell_id+ '.xlsx'
# cycle = pd.read_excel(filename,sheet_name='cycle')
# step = pd.read_excel(filename,sheet_name='step')
# details = pd.read_excel(filename,sheet_name='record')

# cycle.to_csv(cell_id+'_cycle.csv')
# step.to_csv(cell_id+'_step.csv')
# details.to_csv(cell_id+'_details.csv')

# %% [markdown]
# ## for cell 4

# %%
################ This is second time testing data
# cell_id = '20240306002'

# filename ='./Cell_raw_data/'+cell_id+ '.xlsx'
# cycle = pd.read_excel(filename,sheet_name='cycle')
# step = pd.read_excel(filename,sheet_name='step')
# details = pd.read_excel(filename,sheet_name='record')

# cycle.to_csv(cell_id+'_cycle.csv')
# step.to_csv(cell_id+'_step.csv')
# details.to_csv(cell_id+'_details.csv')

# %% [markdown]
# ## Open the cell data ready for process

# %%
cell_id = '20240830001'

df_cycle1 = pd.read_csv(cell_id+'_cycle.csv')
df_step1 = pd.read_csv(cell_id+'_step.csv')
df_details1 = pd.read_csv(cell_id+'_details.csv')


# cell_id = '20240305001'

# df_cycle2 = pd.read_csv(cell_id+'_cycle.csv')
# df_step2 = pd.read_csv(cell_id+'_step.csv')
# df_details2 = pd.read_csv(cell_id+'_details.csv')

# cell_id = '20240306001'

# df_cycle3 = pd.read_csv(cell_id+'_cycle.csv')
# df_step3 = pd.read_csv(cell_id+'_step.csv')
# df_details3 = pd.read_csv(cell_id+'_details.csv')

# cell_id = '20240306002'

# df_cycle4 = pd.read_csv(cell_id+'_cycle.csv')
# df_step4 = pd.read_csv(cell_id+'_step.csv')
# df_details4 = pd.read_csv(cell_id+'_details.csv')

# %% [markdown]
# # Process the thickness data per charge step

# %% [markdown]
# ## cell 1 data analysis-charge

# %%
df_details1['Step Type'].unique()
# Out:
# array(['Rest', 'CC DChg', 'CC Chg', 'CCCV Chg'], dtype=object)

# %%
df =df_details1

# the cell nominal capacity as 2.8 Ah
# cycle_5 @ 0.28 A = 0.05 C
char_data1 = df.loc[df['Step Index']== 6]
char_data1['thickness'] = char_data1['V1(V)'].values -char_data1['V1(V)'].values[0]

# cycle_6 @ 0.56 A = 0.1 C
char_data2 = df.loc[df['Step Index']== 12]
char_data2['thickness'] = char_data2['V1(V)'].values -char_data2['V1(V)'].values[0]

# cycle_7 @ 0.94 A = 0.2 C
char_data3 = df.loc[df['Step Index']== 18]
char_data3['thickness'] = char_data3['V1(V)'].values -char_data3['V1(V)'].values[0]

# cycle_8 @ 1.4 A = 1/3 C
char_data4 = df.loc[df['Step Index']== 24]
char_data4['thickness'] = char_data4['V1(V)'].values -char_data4['V1(V)'].values[0]

# cycle_8 @ 1.4 A = 0.5 C
char_data5 = df.loc[df['Step Index']== 30]
char_data5['thickness'] = char_data5['V1(V)'].values -char_data5['V1(V)'].values[0]

# cycle_8 @ 1.4 A = 0.75 C
char_data6 = df.loc[df['Step Index']== 36]
char_data6['thickness'] = char_data6['V1(V)'].values -char_data6['V1(V)'].values[0]

# # cycle_8 @ 1.4 A = 1.0 C
char_data7 = df.loc[df['Step Index']== 42]
char_data7['thickness'] = char_data7['V1(V)'].values -char_data7['V1(V)'].values[0]

# # cycle_8 @ 1.4 A = 1.5 C
# char_data8 = df[locs[8]:locs[9]]
# char_data8['thickness'] = char_data8['V1(V)'].values -char_data8['V1(V)'].values[0]

# # cycle_8 @ 1.4 A = 1.5 C
# char_data9 = df[locs[9]:]
# char_data9['thickness'] = char_data9['V1(V)'].values -char_data9['V1(V)'].values[0]
# Out:
# C:\Users\Jian Zhang\AppData\Local\Temp\ipykernel_21632\2652739510.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   char_data1['thickness'] = char_data1['V1(V)'].values -char_data1['V1(V)'].values[0]
# C:\Users\Jian Zhang\AppData\Local\Temp\ipykernel_21632\2652739510.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   char_data2['thickness'] = char_data2['V1(V)'].values -char_data2['V1(V)'].values[0]
# ...

# %%
# df =df_details1
# df=df.loc[(df['Step Type']=='CC Chg')|(df['Step Type']=='CCCV Chg')]

# locs = list(np.where((df['Capacity(Ah)'] == 0))[0])
# locs
# # the cell nominal capacity as 2.8 Ah
# # cycle_5 @ 0.28 A = 0.05 C
# char_data1 = df[locs[0]:locs[1]]
# char_data1['thickness'] = char_data1['V1(V)'].values -char_data1['V1(V)'].values[0]

# # cycle_6 @ 0.56 A = 0.1 C
# char_data2 = df[locs[2]:locs[3]]
# char_data2['thickness'] = char_data2['V1(V)'].values -char_data2['V1(V)'].values[0]

# # cycle_7 @ 0.94 A = 0.2 C
# char_data3 = df[locs[3]:locs[4]]
# char_data3['thickness'] = char_data3['V1(V)'].values -char_data3['V1(V)'].values[0]

# # cycle_8 @ 1.4 A = 1/3 C
# char_data4 = df[locs[4]:locs[5]]
# char_data4['thickness'] = char_data4['V1(V)'].values -char_data4['V1(V)'].values[0]

# # cycle_8 @ 1.4 A = 0.5 C
# char_data5 = df[locs[5]::]
# char_data5['thickness'] = char_data5['V1(V)'].values -char_data5['V1(V)'].values[0]

# # # cycle_8 @ 1.4 A = 1 C
# # char_data6 = df[locs[6]:locs[7]]
# # char_data6['thickness'] = char_data6['V1(V)'].values -char_data6['V1(V)'].values[0]

# # # cycle_8 @ 1.4 A = 1.5 C
# # char_data7 = df[locs[7]:locs[8]]
# # char_data7['thickness'] = char_data7['V1(V)'].values -char_data7['V1(V)'].values[0]

# # # cycle_8 @ 1.4 A = 1.5 C
# # char_data8 = df[locs[8]:locs[9]]
# # char_data8['thickness'] = char_data8['V1(V)'].values -char_data8['V1(V)'].values[0]

# # # cycle_8 @ 1.4 A = 1.5 C
# # char_data9 = df[locs[9]:]
# # char_data9['thickness'] = char_data9['V1(V)'].values -char_data9['V1(V)'].values[0]
# Out:
# C:\Users\Jian Zhang\AppData\Local\Temp\ipykernel_21632\3665510239.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   char_data1['thickness'] = char_data1['V1(V)'].values -char_data1['V1(V)'].values[0]
# C:\Users\Jian Zhang\AppData\Local\Temp\ipykernel_21632\3665510239.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   char_data2['thickness'] = char_data2['V1(V)'].values -char_data2['V1(V)'].values[0]
# ...

# %% [markdown]
# ## Cell 2 data for charge

# %%
# df =df_details2
# df=df.loc[df['Step Type']=='CCCV Chg']
# locs = list(np.where((df['Capacity(Ah)'] == 0))[0])
# locs
# # the cell nominal capacity as 2.8 Ah
# # cycle_5 @ 1.4 A = 0.5 C
# char_data5 = df[locs[0]:locs[1]]
# char_data5['thickness'] = char_data5['V1(V)'].values -char_data5['V1(V)'].values[0]

# # cycle_6 @ 2.8 A = 1.0 C
# char_data6 = df[locs[1]:locs[2]]
# char_data6['thickness'] = char_data6['V1(V)'].values -char_data6['V1(V)'].values[0]

# # cycle_7 @ 4.2 A = 1.5 C
# char_data7 = df[locs[2]:locs[3]]
# char_data7['thickness'] = char_data7['V1(V)'].values -char_data7['V1(V)'].values[0]

# # cycle_8 @ 5.6 A = 2.0 C
# char_data8 = df[locs[3]:]
# char_data8['thickness'] = char_data8['V1(V)'].values -char_data8['V1(V)'].values[0]

# %% [markdown]
# ## cell 3 data charg

# %%
# df =df_details3
# df=df.loc[df['Step Type']=='CCCV Chg']
# locs = list(np.where((df['Capacity(Ah)'] == 0))[0])
# locs
# # # the cell nominal capacity as 2.8 Ah
# # cycle_9 @ 2.1 A = 0.75 C
# char_data9 = df[locs[0]:]
# char_data9['thickness'] = char_data9['V1(V)'].values -char_data9['V1(V)'].values[0]

# %% [markdown]
# ## cell 4 data charge

# %%
# df =df_details4
# df=df.loc[df['Step Type']=='CCCV Chg']
# locs = list(np.where((df['Capacity(Ah)'] == 0))[0])
# locs
# # # the cell nominal capacity as 2.8 Ah
# # cycle_10 @ 1.4 A = 0.5 C
# char_data10 = df[locs[0]:locs[1]]
# char_data10['thickness'] = char_data10['V1(V)'].values -char_data10['V1(V)'].values[0]

# # cycle_11 @ 2.8 A = 1.0 C
# char_data11 = df[locs[1]:locs[2]]
# char_data11['thickness'] = char_data11['V1(V)'].values -char_data11['V1(V)'].values[0]

# # cycle_12 @ 4.2 A = 1.5 C
# char_data12 = df[locs[2]:locs[3]]
# char_data12['thickness'] = char_data12['V1(V)'].values -char_data12['V1(V)'].values[0]

# # cycle_13 @ 5.6 A = 2.0 C
# char_data13 = df[locs[3]:]
# char_data13['thickness'] = char_data13['V1(V)'].values -char_data13['V1(V)'].values[0]

# %% [markdown]
# ## Charge Capacity voltage thickness

# %%
import matplotlib.pyplot as plt
# From cell #1
x1 = char_data1['Capacity(Ah)']
y1_v = char_data1['Voltage(V)']
y1_thick = char_data1['thickness']

x2 = char_data2['Capacity(Ah)']
y2_v = char_data2['Voltage(V)']
y2_thick = char_data2['thickness']

x3 = char_data3['Capacity(Ah)']
y3_v = char_data3['Voltage(V)']
y3_thick = char_data3['thickness']

x4 = char_data4['Capacity(Ah)']
y4_v = char_data4['Voltage(V)']
y4_thick = char_data4['thickness']

x5 = char_data5['Capacity(Ah)']
y5_v = char_data5['Voltage(V)']
y5_thick = char_data5['thickness']

x6 = char_data6['Capacity(Ah)']
y6_v = char_data6['Voltage(V)']
y6_thick = char_data6['thickness']

x7 = char_data7['Capacity(Ah)']
y7_v = char_data7['Voltage(V)']
y7_thick = char_data7['thickness']

# x8 = char_data8['Capacity(Ah)']
# y8_v = char_data8['Voltage(V)']
# y8_thick = char_data8['thickness']

# x9 = char_data9['Capacity(Ah)']
# y9_v = char_data9['Voltage(V)']
# y9_thick = char_data9['thickness']


# # for cell 4
# x10 = char_data10['Capacity(Ah)']
# y10_v = char_data10['Voltage(V)']
# y10_thick = char_data10['thickness']

# x11 = char_data11['Capacity(Ah)']
# y11_v = char_data11['Voltage(V)']
# y11_thick = char_data11['thickness']

# x12 = char_data12['Capacity(Ah)']
# y12_v = char_data12['Voltage(V)']
# y12_thick = char_data12['thickness']

# x13 = char_data13['Capacity(Ah)']
# y13_v = char_data13['Voltage(V)']
# y13_thick = char_data13['thickness']

# Create a figure with two subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))

ax1 = axes[0]

ax1.plot(x1,y1_v,label = '0.05 C Voltage')
ax1.plot(x2,y2_v,label = '0.1 C Voltage')
ax1.plot(x3,y3_v,label = '0.2 C Voltage')
ax1.plot(x4,y4_v,label = '1/3 C Voltage')
ax1.plot(x5,y5_v,label = '0.5 C Voltage')
ax1.plot(x6,y6_v,label = '0.75 C Voltage')
ax1.plot(x7,y7_v,label = '1.0 C Voltage')
# ax1.plot(x8,y8_v,label = '2.0 C Voltage')
# ax1.plot(x9,y9_v,label = '3.0 C Voltage')


ax1.set_xlabel('Capacity (Ah)')
ax1.set_ylabel('Voltage (V)')
ax1.set_title('Charge Voltage-Cpacity')

ax1.grid()
ax1.legend()

ax2 = axes[1]

ax2.plot(x1,y1_thick,label = '0.05 C Thickness')
ax2.plot(x2,y2_thick,label = '0.1 C Thickness')
ax2.plot(x3,y3_thick,label = '0.2 C Thickness')
ax2.plot(x4,y4_thick,label = '1/3 C Thickness')
ax2.plot(x5,y5_thick,label = '0.5 C Thickness')
ax2.plot(x6,y6_thick,label = '0.75 C Thickness')
ax2.plot(x7,y7_thick,label = '1.0 C Thickness')
# ax2.plot(x8,y8_thick,label = '2.0 C Thickness')
# ax2.plot(x9,y9_thick,label = '3.0 C Thickness')


ax2.set_xlabel('Capacity (Ah)')
ax2.set_ylabel('Thickness Growth (mm)')
ax2.set_title('Charge Voltage-Thickness Growth')

ax2.grid()
ax2.legend()


# fig.savefig('Li Plating_with_ext_force cell2.png', dpi=1000)

# %% [markdown]
# * General conclusion
# * The thickness vs. capacity shape evolve from 0.1C to 2C, they have changed accordingly.
# * If we want to link the thickness growth shape to the Li plating, we need the experimental evidence.
# * Option 1. reference electrode: To measure Li vs. Gr electrode to know the voltage
# * Option 2. Tear down to check the Li plating on Gr layer

# %%
# Create a figure with two subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))

ax1 = axes[0]
ax1.plot(x11,y11_v,label = '1.0 2 C Voltage')

# %% [markdown]
# ## Discharge capacity voltage thickness

# %%
df =df_details1
df=df.loc[(df['Step Type']=='CC DChg')
         &(abs(df['Current(A)'])>1)]
locs = list(np.where((df['Capacity(Ah)'] == 0))[0])
locs

# the cell nominal capacity as 2.8 Ah

# cycle_1 @ 1.4 A = 0.5 C
dchar_data1 = df[locs[1]:locs[2]]
dchar_data1['thickness'] = dchar_data1['V1(V)'].values -dchar_data1['V1(V)'].values[0]

# cycle_2 @ 2.8 A = 1 C
dchar_data2 = df[locs[2]:locs[3]]
dchar_data2['thickness'] = dchar_data2['V1(V)'].values -dchar_data2['V1(V)'].values[0]

# cycle_3 @ 4.2 A = 1.5 C
dchar_data3 = df[locs[3]:locs[4]]
dchar_data3['thickness'] = dchar_data3['V1(V)'].values -dchar_data3['V1(V)'].values[0]

# cycle_4 @ 5.6 A = 2.0 C
dchar_data4 = df[locs[4]:]
dchar_data4['thickness'] = dchar_data4['V1(V)'].values -dchar_data4['V1(V)'].values[0]

# %%
df =df_details2
df=df.loc[(df['Step Type']=='CC DChg')
         &(abs(df['Current(A)'])>1)]

locs = list(np.where((df['Capacity(Ah)'] == 0))[0])
locs
# the cell nominal capacity as 2.8 Ah
# cycle_5 @ 0.28 A = 0.1 C
dchar_data5 = df[locs[0]:locs[1]]
dchar_data5['thickness'] = dchar_data5['V1(V)'].values -dchar_data5['V1(V)'].values[0]

# cycle_6 @ 0.56 A = 0.2 C
dchar_data6 = df[locs[1]:locs[2]]
dchar_data6['thickness'] = dchar_data6['V1(V)'].values -dchar_data6['V1(V)'].values[0]

# cycle_7 @ 0.95 A = 1/3 C
dchar_data7 = df[locs[2]:locs[3]]
dchar_data7['thickness'] = dchar_data7['V1(V)'].values -dchar_data7['V1(V)'].values[0]

# cycle_7 @ 1.4 A = 0.5 C
dchar_data8 = df[locs[3]:]
dchar_data8['thickness'] = dchar_data8['V1(V)'].values -dchar_data8['V1(V)'].values[0]

# %%
import matplotlib.pyplot as plt
# From cell #1
x1 = dchar_data1['Capacity(Ah)']
y1_v = dchar_data1['Voltage(V)']
y1_thick = dchar_data1['thickness']

x2 = dchar_data2['Capacity(Ah)']
y2_v = dchar_data2['Voltage(V)']
y2_thick = dchar_data2['thickness']

x3 = dchar_data3['Capacity(Ah)']
y3_v = dchar_data3['Voltage(V)']
y3_thick = dchar_data3['thickness']

x4 = dchar_data4['Capacity(Ah)']
y4_v = dchar_data4['Voltage(V)']
y4_thick = dchar_data4['thickness']

# From cell #2
x5 = dchar_data5['Capacity(Ah)']
y5_v = dchar_data5['Voltage(V)']
y5_thick = dchar_data5['thickness']

x6 = dchar_data6['Capacity(Ah)']
y6_v = dchar_data6['Voltage(V)']
y6_thick = dchar_data6['thickness']

x7 = dchar_data7['Capacity(Ah)']
y7_v = dchar_data7['Voltage(V)']
y7_thick = dchar_data7['thickness']

x8 = dchar_data8['Capacity(Ah)']
y8_v = dchar_data8['Voltage(V)']
y8_thick = dchar_data8['thickness']

# Create a figure with two subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))

ax1 = axes[0]

ax1.plot(x5,y5_v,label = '0.1 C Voltage')
ax1.plot(x6,y6_v,label = '0.2 C Voltage')
ax1.plot(x7,y7_v,label = '1/3 C Voltage')
ax1.plot(x8,y8_v,label = '0.5 C  2 Voltage')
ax1.plot(x1,y1_v,label = '0.5 C Voltage')
ax1.plot(x2,y2_v,label = '1.0 C Voltage')
ax1.plot(x3,y3_v,label = '1.5 C Voltage')
ax1.plot(x4,y4_v,label = '2.0 C Voltage')

ax1.set_xlabel('Capacity (Ah)')
ax1.set_ylabel('Voltage (V)')
ax1.set_title('Discharge Voltage-Cpacity')

ax1.grid()
ax1.legend()


ax2 = axes[1]
ax2.plot(x5,y5_thick,label = '0.1 C Thickness')
ax2.plot(x6,y6_thick,label = '0.2 C Thickness')
ax2.plot(x7,y7_thick,label = '1/3 C Thickness')
ax2.plot(x8,y8_thick,label = '0.5 C 2 Thickness')
ax2.plot(x1,y1_thick,label = '0.5 C Thickness')
ax2.plot(x2,y2_thick,label = '1.0 C Thickness')
ax2.plot(x3,y3_thick,label = '1.5 C Thickness')
ax2.plot(x4,y4_thick,label = '2.0 C Thickness')

ax2.set_xlabel('Capacity (Ah)')
ax2.set_ylabel('Thickness Growth (um)')
ax2.set_title('Discharge Voltage-Thickness Growth')

ax2.grid()
ax2.legend()
